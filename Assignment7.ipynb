# %% [markdown]
# <a href="https://colab.research.google.com/github/2203A51251/NLP_Lab/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Use a simple dataset for English-to-French translation. You can either use a small dataset like this or download a more extensive dataset such as the Tab-delimited Bilingual Sentence Pairs dataset from Tatoeba or Parallel Corpus from the European Parliament.
#
# Example data (small English to French pairs)
#
# data = [ ("hello", "bonjour"), ("how are you", "comment ça va"), ("I am fine", "je vais bien"), ("what is your name", "comment tu t'appelles"), ("my name is", "je m'appelle"), ("thank you", "merci"), ("goodbye", "au revoir") ]  [CO4]
#
#
#
# (a) Data Preprocessing
#
# (b) Build Seq2Seq Model
#
# (c) Preparing the Data for Training
#
# (d) Train the model on the dataset
#
# (e) Inference Setup for Translation
#
# (f) Translate New Sentences
#
# (g) Experimenting and Improving the Model by large dataset and hyper tune parameter.

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# %% [markdown]
# (a) Data Preprocessing

# %%
# Example data (small English to French pairs)
data = [("hello", "bonjour"),
        ("how are you", "comment ça va"),
        ("I am fine", "je vais bien"),
        ("what is your name", "comment tu t'appelles"),
        ("my name is", "je m'appelle"),
        ("thank you", "merci"),
        ("goodbye", "au revoir")]

# Splitting the data into input (English) and output (French) pairs
english_sentences, french_sentences = zip(*data)

# Tokenize English sentences
eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english_sentences)
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
eng_word_index = eng_tokenizer.word_index
max_eng_len = max(len(seq) for seq in eng_sequences)

# Tokenize French sentences
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# Vocabulary sizes
eng_vocab_size = len(eng_word_index) + 1
fr_vocab_size = len(fr_word_index) + 1

# %% [markdown]
# (b) Build Seq2Seq Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Encoder
latent_dim = 256
encoder_inputs = Input(shape=(max_eng_len,))
enc_emb = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(max_fr_len,))
dec_emb_layer = Embedding(fr_vocab_size, latent_dim)
dec_emb = dec_emb_layer(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)
decoder_dense = Dense(fr_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8             │ (None, 4)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_9             │ (None, 3)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_6 (Embedding)   │ (None, 4, 256)         │          3,840 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_7 (Embedding)   │ (None, 3, 256)         │          3,584 │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_7 (LSTM)             │ [(None, 256), (None,   │        525,312 │ embedding_6[0][0]      │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_8 (LSTM)             │ [(None, 3, 256),       │        525,312 │ embedding_7[0][0],     │
# │                           │ (None, 256), (None,    │                │ lstm_7[0][1],          │
# │                           │ 256)]                  │                │ lstm_7[0][2]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 3, 14)          │          3,598 │ lstm_8[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,061,646 (4.05 MB)
#  Trainable params: 1,061,646 (4.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# (c) Preparing the Data for Training

# %%
# Preparing decoder target data (shifted French sentences)
fr_padded_target = np.zeros_like(fr_padded)
fr_padded_target[:, :-1] = fr_padded[:, 1:]

# Train/Val Split
train_size = int(0.8 * len(eng_padded))
eng_train, eng_val = eng_padded[:train_size], eng_padded[train_size:]
fr_train, fr_val = fr_padded[:train_size], fr_padded[train_size:]
fr_target_train, fr_target_val = fr_padded_target[:train_size], fr_padded_target[train_size:]

# %% [markdown]
#  (d) Train the model on the dataset

# %%
batch_size = 64
epochs = 100
history = model.fit([eng_train, fr_train], fr_target_train,batch_size=batch_size,epochs=epochs,
                    validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5333 - loss: 2.6264 - val_accuracy: 0.8333 - val_loss: 2.5462
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5333 - loss: 2.5759 - val_accuracy: 0.8333 - val_loss: 2.4680
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 2.5199 - val_accuracy: 0.8333 - val_loss: 2.3719
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5333 - loss: 2.4531 - val_accuracy: 0.8333 - val_loss: 2.2488
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 2.3694 - val_accuracy: 0.8333 - val_loss: 2.0882
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5333 - loss: 2.2621 - val_accuracy: 0.8333 - val_loss: 1.8794
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 2.1242 - val_accuracy: 0.8333 - val_loss: 1.6155
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 1.9516 - val_accuracy: 0.8333 - val_loss: 1.3098
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5333 - loss: 1.7538 - val_accuracy: 0.8333 - val_loss: 1.0273
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5333 - loss: 1.5669 - val_accuracy: 0.8333 - val_loss: 0.8755
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 1.4568 - val_accuracy: 0.8333 - val_loss: 0.8887
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5333 - loss: 1.4754 - val_accuracy: 0.8333 - val_loss: 0.9651
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5333 - loss: 1.5302 - val_accuracy: 0.8333 - val_loss: 1.0099
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 1.5129 - val_accuracy: 0.8333 - val_loss: 1.0140
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5333 - loss: 1.4344 - val_accuracy: 0.8333 - val_loss: 0.9948
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.3394 - val_accuracy: 0.8333 - val_loss: 0.9707
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.5333 - loss: 1.2614 - val_accuracy: 0.8333 - val_loss: 0.9541
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 1.2125 - val_accuracy: 0.8333 - val_loss: 0.9491
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 1.1873 - val_accuracy: 0.8333 - val_loss: 0.9540
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5333 - loss: 1.1726 - val_accuracy: 0.8333 - val_loss: 0.9644
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5333 - loss: 1.1564 - val_accuracy: 0.8333 - val_loss: 0.9770
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5333 - loss: 1.1317 - val_accuracy: 0.8333 - val_loss: 0.9907
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.5333 - loss: 1.0957 - val_accuracy: 0.8333 - val_loss: 1.0067
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5333 - loss: 1.0492 - val_accuracy: 0.8333 - val_loss: 1.0277
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 0.9953 - val_accuracy: 0.8333 - val_loss: 1.0564
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6000 - loss: 0.9382 - val_accuracy: 0.8333 - val_loss: 1.0948
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8333 - val_loss: 3.5565
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8333 - val_loss: 3.5627
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8333 - val_loss: 3.5678
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8333 - val_loss: 3.5719
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8333 - val_loss: 3.5751
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.8333 - val_loss: 3.5775
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8333 - val_loss: 3.5794
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8333 - val_loss: 3.5808
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8333 - val_loss: 3.5820
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8333 - val_loss: 3.5831
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8333 - val_loss: 3.5844
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8333 - val_loss: 3.5858
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.5875
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8333 - val_loss: 3.5894
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.5917
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.5943
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 3.5970
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 3.5999
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 3.6027
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8333 - val_loss: 3.6055
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.6082
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.6107
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8333 - val_loss: 3.6129
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8333 - val_loss: 3.6149
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8333 - val_loss: 3.6166

# %% [markdown]
# (e) Inference Setup for Translation

# %%
# Inference Encoder
encoder_model = Model(encoder_inputs, encoder_states)

# Inference Decoder
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
dec_emb2 = dec_emb_layer(decoder_inputs)
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)
decoder_model = Model([decoder_inputs] + decoder_states_inputs,[decoder_outputs2] + decoder_states2)

# %% [markdown]
# (f) Translate New Sentences

# %%
# Add 'start' and 'end' tokens to French sentences
french_sentences_with_tokens = ['start ' + sent + ' end' for sent in french_sentences]

# Tokenize French sentences with start and end tokens
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences_with_tokens)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences_with_tokens)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        if sampled_word == 'end' or len(decoded_sentence) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]

    return decoded_sentence

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Get the index of the most likely next word
        sampled_token_index = np.argmax(output_tokens[0, -1, :])

        # Retrieve the corresponding word for the token index
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        # Handle the case where the word is not found
        if sampled_word is None:
            print(f"Warning: No word found for token index {sampled_token_index}")
            stop_condition = True
        elif sampled_word == 'end' or len(decoded_sentence.split()) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        # Update the target sequence to the predicted word
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states for the next iteration
        states_value = [h, c]

    return decoded_sentence

# %%
# Testing with a new sentence
test_sentence = "hello"
test_sequence = eng_tokenizer.texts_to_sequences([test_sentence])
test_sequence = pad_sequences(test_sequence, maxlen=max_eng_len, padding='post')

translation = decode_sequence(test_sequence)
print(f"Translation: {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Warning: No word found for token index 0
# Translation:

# %% [markdown]
# (g) Experimenting and Improving the Model with a Larger Dataset

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import Adam

# Define the latent_dim and other hyperparameters
latent_dim = 256
eng_vocab_size = 15  # Example value; replace with actual vocab size
fr_vocab_size = 15   # Example value; replace with actual vocab size
embedding_dim = 128  # Size of the embedding vectors

# Define encoder
encoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
encoder_embedding = Embedding(input_dim=eng_vocab_size, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_sequences=True)(encoder_embedding)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_lstm)
encoder_states = [state_h, state_c]

# Define decoder
decoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
decoder_embedding = Embedding(input_dim=fr_vocab_size, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True)(decoder_embedding, initial_state=encoder_states)
decoder_outputs = Dense(fr_vocab_size, activation='softmax')(decoder_lstm)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
opt = Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Check the shapes of the training data
# Ensure eng_train, fr_train, and fr_target_train have the appropriate shapes
print(f"eng_train shape: {eng_train.shape}, fr_train shape: {fr_train.shape}, fr_target_train shape: {fr_target_train.shape}")

# Train the model
model.fit([eng_train, fr_train], fr_target_train, batch_size=batch_size, epochs=200, validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# eng_train shape: (5, 4), fr_train shape: (5, 3), fr_target_train shape: (5, 3)
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.0000e+00 - loss: 2.7091 - val_accuracy: 0.3333 - val_loss: 2.7010
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5333 - loss: 2.6969 - val_accuracy: 0.8333 - val_loss: 2.6875
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 2.6843 - val_accuracy: 0.8333 - val_loss: 2.6729
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5333 - loss: 2.6707 - val_accuracy: 0.8333 - val_loss: 2.6564
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5333 - loss: 2.6557 - val_accuracy: 0.8333 - val_loss: 2.6374
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5333 - loss: 2.6386 - val_accuracy: 0.8333 - val_loss: 2.6149
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5333 - loss: 2.6188 - val_accuracy: 0.8333 - val_loss: 2.5880
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 2.5953 - val_accuracy: 0.8333 - val_loss: 2.5555
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 2.5672 - val_accuracy: 0.8333 - val_loss: 2.5157
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 2.5332 - val_accuracy: 0.8333 - val_loss: 2.4670
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5333 - loss: 2.4917 - val_accuracy: 0.8333 - val_loss: 2.4071
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5333 - loss: 2.4407 - val_accuracy: 0.8333 - val_loss: 2.3331
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5333 - loss: 2.3778 - val_accuracy: 0.8333 - val_loss: 2.2417
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5333 - loss: 2.3001 - val_accuracy: 0.8333 - val_loss: 2.1289
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5333 - loss: 2.2046 - val_accuracy: 0.8333 - val_loss: 1.9906
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 2.0883 - val_accuracy: 0.8333 - val_loss: 1.8234
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 1.9508 - val_accuracy: 0.8333 - val_loss: 1.6280
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5333 - loss: 1.7978 - val_accuracy: 0.8333 - val_loss: 1.4160
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5333 - loss: 1.6490 - val_accuracy: 0.8333 - val_loss: 1.2182
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5333 - loss: 1.5431 - val_accuracy: 0.8333 - val_loss: 1.0818
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 1.5262 - val_accuracy: 0.8333 - val_loss: 1.0328
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5333 - loss: 1.5846 - val_accuracy: 0.8333 - val_loss: 1.0357
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.5333 - loss: 1.6308 - val_accuracy: 0.8333 - val_loss: 1.0477
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5333 - loss: 1.6214 - val_accuracy: 0.8333 - val_loss: 1.0558
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 0.8507 - val_accuracy: 0.8333 - val_loss: 2.0575
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5333 - loss: 0.8278 - val_accuracy: 0.8333 - val_loss: 2.1170
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5333 - loss: 0.8029 - val_accuracy: 0.8333 - val_loss: 2.1743
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6000 - loss: 0.7760 - val_accuracy: 0.8333 - val_loss: 2.2300
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6000 - loss: 0.7476 - val_accuracy: 0.8333 - val_loss: 2.2857
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7333 - loss: 0.7184 - val_accuracy: 0.6667 - val_loss: 2.3429
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9333 - loss: 0.6890 - val_accuracy: 0.6667 - val_loss: 2.4032
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.6594 - val_accuracy: 0.6667 - val_loss: 2.4671
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.6289 - val_accuracy: 0.6667 - val_loss: 2.5350
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 1.0000 - loss: 0.5970 - val_accuracy: 0.6667 - val_loss: 2.6064
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.5638 - val_accuracy: 0.6667 - val_loss: 2.6802
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.5297 - val_accuracy: 0.6667 - val_loss: 2.7549
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.4956 - val_accuracy: 0.6667 - val_loss: 2.8284
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.4617 - val_accuracy: 0.6667 - val_loss: 2.8985
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.4281 - val_accuracy: 0.6667 - val_loss: 2.9636
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.3944 - val_accuracy: 0.6667 - val_loss: 3.0236
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 1.0000 - loss: 0.3611 - val_accuracy: 0.6667 - val_loss: 3.0796
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.3289 - val_accuracy: 0.6667 - val_loss: 3.1334
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.2983 - val_accuracy: 0.6667 - val_loss: 3.1871
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.2696 - val_accuracy: 0.6667 - val_loss: 3.2420
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.2426 - val_accuracy: 0.6667 - val_loss: 3.2988
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.2171 - val_accuracy: 0.6667 - val_loss: 3.3570
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.1935 - val_accuracy: 0.6667 - val_loss: 3.4156
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.1722 - val_accuracy: 0.6667 - val_loss: 3.4728
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.1534 - val_accuracy: 0.6667 - val_loss: 3.5269
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.1365 - val_accuracy: 0.6667 - val_loss: 3.5769
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.1215 - val_accuracy: 0.6667 - val_loss: 3.6232
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.1082 - val_accuracy: 0.6667 - val_loss: 3.6670
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0967 - val_accuracy: 0.6667 - val_loss: 3.7099
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0867 - val_accuracy: 0.6667 - val_loss: 3.7523
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 1.0000 - loss: 0.0780 - val_accuracy: 0.6667 - val_loss: 3.7932
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0704 - val_accuracy: 0.6667 - val_loss: 3.8305
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0638 - val_accuracy: 0.6667 - val_loss: 3.8624
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0581 - val_accuracy: 0.6667 - val_loss: 3.8884
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0531 - val_accuracy: 0.6667 - val_loss: 3.9094
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0487 - val_accuracy: 0.6667 - val_loss: 3.9275
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0447 - val_accuracy: 0.6667 - val_loss: 3.9446
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 0.6667 - val_loss: 3.9619
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0382 - val_accuracy: 0.6667 - val_loss: 3.9793
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0354 - val_accuracy: 0.6667 - val_loss: 3.9959
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0329 - val_accuracy: 0.6667 - val_loss: 4.0107
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0307 - val_accuracy: 0.6667 - val_loss: 4.0231
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.6667 - val_loss: 4.0336
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0268 - val_accuracy: 0.6667 - val_loss: 4.0432
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 0.6667 - val_loss: 4.0531
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.6667 - val_loss: 4.0638
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: